# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_json('file1.json')

# %%
df['restaurants'].iloc[0][0]['restaurant'].keys()
# Out:
# dict_keys(['has_online_delivery', 'photos_url', 'url', 'price_range', 'apikey', 'user_rating', 'R', 'name', 'cuisines', 'is_delivering_now', 'deeplink', 'menu_url', 'average_cost_for_two', 'book_url', 'switch_to_order_menu', 'offers', 'has_table_booking', 'location', 'featured_image', 'zomato_events', 'currency', 'id', 'thumb', 'establishment_types', 'events_url'])

# %%
zomato = pd.read_csv('zomato.csv', encoding = 'ISO-8859-1')

# %%
zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...           Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...   Botswana Pula(P)               Yes
# 1                          Japanese  ...   Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...   Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...   Botswana Pula(P)                No
# 4                  Japanese, Korean  ...   Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
zomato.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

class CSVNotFoundException(Exception):
    pass

class InvalidRangeException(Exception):
    pass

class ContentFiltering(object):
    
    def __init__(self, csvPath, countryPath):
        self.dataset = self.get_data_csv(csvPath)
        self.countryCode = self.get_country_csv(countryPath)
        self.create_cuisine_bag()   
    
    def filter_online_delivery(self, data, param):
        data = data[data['Has Online delivery'] == param]
        return data
    
    def filter_table_booking(self, data, param):
        data = data[data['Has Table booking'] == param]
        return data
    
    def filter_price_range(self, data, lower_range = 1, upper_range = 5):
        
        if (type(data) != pd.DataFrame):
            raise(TypeError('Not a dataframe'))
            
        if not (lower_range >= 1 and upper_range <= 5):
            raise(InvalidRangeException('only ranging from 1 to 5'))
        mask1 = data['Price range'] >= lower_range
        mask2 = data['Price range'] <= upper_range
        data =  data[mask1 & mask2]
        return data
    
    def filter_avg_cost(self, dataset, lower_range = 0, upper_range= 800000):
        if (type(data) != pd.DataFrame):
            raise(TypeError('Not a dataframe'))
            
        mask1 = data['Average Cost for two'] >= lower_range
        mask2 = data['Average Cost for two'] <= upper_range
        data =  data[mask1 & mask2]
        return data
    
    
    def country_filter(self, country):
        if type(country) != str:
            raise(TypeError('Country Name is a string'))
        code = self.countryCode[self.countryCode['country'] == country.lower()]['code'][0]
        print (code)
        data = self.dataset[self.dataset['Country Code'] == code]
        return data
    
    def get_country_csv(self, csvPath):

        if not (os.path.exists(csvPath)):
            raise(FileNotFoundError('{} is not found'.format(csvPath)))

        if not (os.path.isfile(csvPath)):
            raise(IsADirectoryError('{} is not a file'.format(csvPath)))
        
        if (not csvPath.endswith('.csv')):
            raise(CSVNotFoundException('{} is not a csv'.format(csvPath)))
        
        country_code = pd.read_csv(csvPath, encoding ='ISO-8859-1')
        country_code['country'] = country_code['country'].apply(lambda x: x.lower())
        return country_code
        
    def get_data_csv(self, csvPath):
        if not (os.path.exists(csvPath)):
            raise(FileNotFoundError('{} is not found'.format(csvPath)))

        if not (os.path.isfile(csvPath)):
            raise(IsADirectoryError('{} is not a file'.format(csvPath)))
        
        if (not csvPath.endswith('.csv')):
            raise(CSVNotFoundException('{} is not a csv'.format(csvPath)))
        
        
        print ('Reading data from {}'.format(csvPath))
        dataset = pd.read_csv(csvPath, encoding = 'ISO-8859-1')
        return dataset
    

    def create_cuisine_bag(self):
        slice_strip = lambda x: [y.lower().strip() for y in x] if type(x) != float else x
        bag = set([y for x in self.dataset['Cuisines'].str.split(',').apply(slice_strip) if type(x) != float for y in x ])
        self.cuisine_bag = list(bag)
        
    def filter_cuisine(self, cuisine_list, dataset = None):
        bag = []
        if type(cuisine_list) != list:
            cuisine_list = [cuisine_list]
        print (cuisine_list)
        for l in cuisine_list:
            print (l)
            bag.extend([x for x in filter(lambda x: l in x, self.cuisine_bag)])
        bag_exp = '|'.join([x for x in bag])
        bag_exp = '(' + bag_exp + ')'
        print (bag_exp)
        if (type(dataset) == None):
            dataset = self.dataset
        mask1 = dataset['Cuisines'].apply(lambda x: x.find(bag_exp) != None)
        data = dataset[mask1]
        #print (data)
        return data
    
    def filter_city(self, city):
        if city == None:
            raise(TypeError('City is not present'))
        mask = self.dataset['City'].apply(lambda x: city.lower() in x.lower())
        data = self.dataset[mask]
        #print (data)
        return data
    
    def filter_rating(self, dataset, min_rating):
        
        if type(min_rating) is not float:
            raise(TypeError('Only float values allowed'))
        elif not (min_rating >= 1) and (min_rating <= 5):
            raise(InvalidRangeException('Only from 1 to 5'))
        
        mask = dataset['Aggregate rating'] >= min_rating
        data = dataset[mask]
        return data

# %%
def filter_data(country = None, city = None, cuisine = None, rating = 1, price_min_rate = 1, price_max_rate = 5, table_book = 'No', online_order = 'No'):
    
    clb = CollaborativeFilter('zomato.csv', 'Country-code.csv')
    if type(country) == str:
        print(country)
        data = clb.country_filter(country)
    elif type(city) == str:
        data = clb.filter_city(city)
    else:
        data = clb.dataset
    data = clb.filter_cuisine(cuisine, data)
    data = clb.filter_online_delivery(data, online_order)
    data = clb.filter_table_booking(data, table_book)
    data = clb.filter_rating(data, rating)
    if (price_min_rate > price_max_rate):
        raise(InvalidRangeException('Lower range should be less than upper range'))
        
    if price_min_rate >= 1 and price_max_rate <= 5:
        data = clb.filter_price_range(data, price_min_rate, price_max_rate)
    elif price_min_rate < 5:
        data = clb.filter_price_range(data, price_min_rate, 5)
    elif price_max_rate <= 5:
        data = clb.filter_price_range(data, 1, price_max_rate)
    else:
        data = clb.filter_avg_cost(data, price_min_rate, price_max_rate)
    
    return data

# %%
clb = ContentFiltering('zomato.csv', 'Country-code.csv')
# Out:
# Reading data from zomato.csv

# %%
data = clb.country_filter('india')
b = clb.filter_price_range(data, 1, 4)
# Out:
# 1

# %%
clb.filter_cuisine(['cafe', 'gujarati'], data)
# Out:
# ['cafe', 'gujarati']
# cafe
# gujarati
# (cafe|restaurant cafe|gujarati)
#       Restaurant ID                           Restaurant Name  Country Code  \
# 624         3400025                                Jahanpanah             1
# 625         3400341                       Rangrezz Restaurant             1
# 626         3400005                   Time2Eat - Mama Chicken             1
# 627         3400021     Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                            Pinch Of Spice             1
# 629         3400325                                 MoMo Cafe             1
# 630         3400059                     Peshawri - ITC Mughal             1
# 631         3400060                     Taj Bano - ITC Mughal             1
# 632         3400348                                    G Thal             1
# 633         3400072              Dawat-e-Nawab - Radisson Blu             1
# 634         3400073               The Latitude - Radisson Blu             1
# 635         3400019                    Dasaprakash Restaurant             1
# 636         3400033                      The Charcoal Chimney             1
# 637         3400346                           Sheroes Hangout             1
# 638         3400350                              Bon Barbecue             1
# 639         3400391                            Chapter 1 Cafe             1
# 640         3400016                             Pind Balluchi             1
# 641         3400105                                 Pizza Hut             1
# 642         3400326          Tea'se Me - Rooftop Tea Boutique             1
# 643         3400392                                Thaaliwala             1
# 644          111895                  650 - The Global Kitchen             1
# 645          110502         Patang - The Revolving Restaurant             1
# 646        18396250                             Huber & Holly             1
# 647          113702                                    @Mango             1
# 648          113433                        Fozzie's Pizzaiolo             1
# 649        18438909                           La Pino'z Pizza             1
# 650        18143128                                     Mocha             1
# 651        18438944    Blue -  Rooftop Cafe Restaurant Bistro             1
# 652          110436        MoMo Cafí© - Courtyard By Marriott             1
# 653        18385201                                  Cryo Lab             1
# ...             ...                                       ...           ...
# 9246        3900070                             Flavours Cafe             1
# 9247        3900057                               Ming Garden             1
# 9248        3900067                               Burger King             1
# 9249        3900050                             Tandoor Villa             1
# 9250        3900009                 eastWEST - Radisson Hotel             1
# 9251        3900010  The Great Kabab Factory - Radisson Hotel             1
# 9252        3900055                    I:ba Cafe & Restaurant             1
# 9253       18346996                3Cherryz Sky Lounge & Cafe             1
# 9254       18246202                           VNS Live Studio             1
# 9255        3900238                Singh's Delight Restaurant             1
# 9256        2800013                                 Pizza Hut             1
# 9257        2800012                                 Pizza Hut             1
# 9258        2800294                        Sri Sairam Parlour             1
# 9259        2800903                  Mekong - Hotel GreenPark             1
# 9260        2800052                The Square - Hotel Novotel             1
# 9261        2800095                               Alpha Hotel             1
# 9262        2800856                           Barbeque Nation             1
# 9263        2800911                               Double Roti             1
# 9264        2800757                              Bake My Wish             1
# 9265        2800096                          Kamat Restaurant             1
# 9266        2800083                             My Restaurant             1
# 9267       18306045                   Percolator Coffee House             1
# 9268        2800897                                Tea Trails             1
# 9269       18285610                               Six Degrees             1
# 9270        2800128                Sea Inn - Raju Gaari Dhaba             1
# 9271        2800100                                  D Cabana             1
# 9272        2800418                                  Kaloreez             1
# 9273        2800881                                   Plot 17             1
# 9274        2800042                          Vista - The Park             1
# 9275        2800019                  Flying Spaghetti Monster             1
#
#            City                                            Address  \
# 624        Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 625        Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...
# 626        Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra
# 627        Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 628        Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...
# 629        Agra  Courtyard by Marriott Agra, Phase 2, Fatehabad...
# 630        Agra          ITC Mughal, Fatehabad Road, Tajganj, Agra
# 631        Agra          ITC Mughal, Fatehabad Road, Tajganj, Agra
# 632        Agra  3/20, KPS Tower, Near Tulsi Talkies, Bypass Ro...
# 633        Agra    Radisson Blu, Taj East Gate Road, Tajganj, Agra
# 634        Agra    Radisson Blu, Taj East Gate Road, Tajganj, Agra
# 635        Agra  Meher Cinema Complex, Gwalior Road, Rakabganj,...
# 636        Agra       Hotel Samovar, Fatehabad Road, Tajganj, Agra
# 637        Agra  Opposite The Gateway Hotel, Fatehabad Road, Ta...
# 638        Agra  Parador Hotel, 3A-3B, Phase 1, Fatehabad Road,...
# 639        Agra  1374 K/1375 K, 2nd floor, Dinesh Nagar, Fatehb...
# 640        Agra  Opposite Saga Emporium, Fatehabad Road, Tajgan...
# 641        Agra  8, Handicraft Nagar, Fatehabad Road, Tajganj, ...
# 642        Agra  Near Purani Mandi Crossing,Fatehabad Road, Taj...
# 643        Agra  Next To ITC Mughal Hotel, Fatehabad Road, Tajg...
# 644   Ahmedabad  Shreekunj Mandapam, Beside Golden Tulip Bunglo...
# 645   Ahmedabad  Chinubhai Tower, Nehru Bridge Corner, Ashram R...
# 646   Ahmedabad  7 B, Circle  B, Opposite Rajpath Club, Sarkhej...
# 647   Ahmedabad        Opposite Sindhu Bhawan, Bodakdev, Ahmedabad
# 648   Ahmedabad  Ground Floor, Maruti Crystal, Opposite Rajpath...
# 649   Ahmedabad  Shop 10,  Circle B, Nyay Marg, Bodakdev, Ahmed...
# 650   Ahmedabad  6-9, Ground Floor, Devashish Business Park, Op...
# 651   Ahmedabad  10th Floor, Balaji Heights Buliding, Behind Ta...
# 652   Ahmedabad  Courtyard By Marriott, Ramdevnagar Cross Road,...
# 653   Ahmedabad  Ground Floor, Arjun Avenue, Opposite Samarthes...
# ...         ...                                                ...
# 9246   Varanasi  1st Floor, Swastik Plaza, Near Ravidas Gate, B...
# 9247   Varanasi           34-B, Ravindra Puri, Near Lanka,Varanasi
# 9248   Varanasi  S 19/1 K, Mint House, Near Hotel Taj, Nai Baza...
# 9249   Varanasi         Near Sbi Atm, Main Road, Nadesar, Varanasi
# 9250   Varanasi   Radisson Hotel, The Mall Road, Nadesar, Varanasi
# 9251   Varanasi   Radisson Hotel, The Mall Road, Nadesar, Varanasi
# 9252   Varanasi               B 3/335, Krimkund, Shivala, Varanasi
# 9253   Varanasi  5th Floor Roof Top,(Above Big Bazaar) Sigra. O...
# 9254   Varanasi  Hotel Varuna Ground Floor, 22 Gulab Bagh, Sigr...
# 9255   Varanasi  1st Floor, Nath Complex, Beside Life Line Hosp...
# 9256      Vizag  52-1-35,36&38, CMR Mall, New Resapavanipalem, ...
# 9257      Vizag  Plot No 47- 10-23/3, 5th Floor, Isnar Khazana ...
# 9258      Vizag  Diamond Park, Railway New Colony Road, Dwaraka...
# 9259      Vizag  Hotel GreenPark, Waltair Main Road, Waltair Up...
# 9260      Vizag    Hotel Novotel, Beach Road, Maharani Peta, Vizag
# 9261      Vizag  28-10-33/6, Jagdamba Commercial Complex, Chitr...
# 9262      Vizag  1st Floor, ATR Towers, Harbour Park Road,  Pan...
# 9263      Vizag  Ground Floor, ATR Towers, Harbour Park Road, P...
# 9264      Vizag   4-70-4, Opposite NCC Canteen, Lawsons Bay, Vizag
# 9265      Vizag  Beach Road, Near Santhi Ashram, Lawsons Bay, V...
# 9266      Vizag  HB Colony, Isukathota, National Highway 5, Bes...
# 9267      Vizag  RK Beach, Maharani Peta, Vizag Visakhapatnam.,...
# 9268      Vizag  7-5-82, Sea Shore Apartments, Southern Portion...
# 9269      Vizag  1-83-29, Opposite Pollock Lotus School, MVP Do...
# 9270      Vizag  Beach Road, Opposite Cyclone Shelter ,   Visak...
# 9271      Vizag  Beach Road, Near Bus Stop, Sagar Nagar, Visakh...
# 9272      Vizag  Plot 95, Opposite St. Lukes Nursing School, Da...
# 9273      Vizag         Plot 17, Gangapur Layout, Siripuram, Vizag
# 9274      Vizag  The Park, Beach Road, Pedda Waltair, Lawsons B...
# 9275      Vizag  10-50-12/F2, Sai Dakshata Complex, Beside Leno...
#
#                                  Locality  \
# 624                            Agra Cantt
# 625                            Agra Cantt
# 626                            Agra Cantt
# 627                           Civil Lines
# 628                           Civil Lines
# 629   Courtyard by Marriott Agra, Tajganj
# 630                   ITC Mughal, Tajganj
# 631                   ITC Mughal, Tajganj
# 632                              Khandari
# 633                 Radisson Blu, Tajganj
# 634                 Radisson Blu, Tajganj
# 635                             Rakabganj
# 636                               Tajganj
# 637                               Tajganj
# 638                               Tajganj
# 639                               Tajganj
# 640                               Tajganj
# 641                               Tajganj
# 642                               Tajganj
# 643                               Tajganj
# 644                              Ambavadi
# 645                           Ashram Road
# 646                              Bodakdev
# 647                              Bodakdev
# 648                              Bodakdev
# 649                              Bodakdev
# 650                              Bodakdev
# 651                              C G Road
# 652      Courtyard By Marriott, Satellite
# 653                          Ellis Bridge
# ...                                   ...
# 9246                                Lanka
# 9247                                Lanka
# 9248                              Nadesar
# 9249                              Nadesar
# 9250              Radisson Hotel, Nadesar
# 9251              Radisson Hotel, Nadesar
# 9252                              Shivala
# 9253                                Sigra
# 9254                                Sigra
# 9255                            Sunderpur
# 9256       CMR Central Mall, Maddilapalem
# 9257                        Dwaraka Nagar
# 9258                        Dwaraka Nagar
# 9259               Hotel GreenPark, Vizag
# 9260         Hotel Novotel, Maharani Peta
# 9261                   Jagadamba Junction
# 9262                    Kirlampudi Layout
# 9263                    Kirlampudi Layout
# 9264                          Lawsons Bay
# 9265                          Lawsons Bay
# 9266                         Maddilapalem
# 9267                        Maharani Peta
# 9268                        Maharani Peta
# 9269                           MVP Colony
# 9270                           Rushikonda
# 9271                          Sagar Nagar
# 9272                            Siripuram
# 9273                            Siripuram
# 9274                The Park, Lawsons Bay
# 9275                      Waltair Uplands
#
#                                  Locality Verbose  Longitude   Latitude  \
# 624                              Agra Cantt, Agra  78.011544  27.161661
# 625                              Agra Cantt, Agra   0.000000   0.000000
# 626                              Agra Cantt, Agra  78.011608  27.160832
# 627                             Civil Lines, Agra  77.998092  27.195928
# 628                             Civil Lines, Agra  78.007553  27.201725
# 629     Courtyard by Marriott Agra, Tajganj, Agra   0.000000   0.000000
# 630                     ITC Mughal, Tajganj, Agra  78.044095  27.160934
# 9274                 The Park, Lawsons Bay, Vizag  83.336840  17.721182
# 9275                       Waltair Uplands, Vizag  83.314942  17.721119
#
#                                                Cuisines  ...   \
# 624                               North Indian, Mughlai  ...
# 625                               North Indian, Mughlai  ...
# 626                                        North Indian  ...
# 627                                          Rajasthani  ...
# 628                      North Indian, Chinese, Mughlai  ...
# 629                              North Indian, European  ...
# 630                               North Indian, Mughlai  ...
# 631                                             Mughlai  ...
# 632                       Rajasthani, Gujarati, Mughlai  ...
# 633                               North Indian, Mughlai  ...
# 634                  North Indian, Chinese, Continental  ...
# 635                              South Indian, Desserts  ...
# 636         North Indian, Chinese, Continental, Mughlai  ...
# 637                         Cafe, North Indian, Chinese  ...
# 638                  North Indian, Chinese, Continental  ...
# 639   Cafe, Italian, Mexican, North Indian, Continental  ...
# 640                               North Indian, Mughlai  ...
# 641                                      Italian, Pizza  ...
# 642         Chinese, Italian, Continental, North Indian  ...
# 643                             North Indian, Fast Food  ...
# 644   Chinese, Italian, North Indian, Mexican, Medit...  ...
# 645                  Continental, Chinese, North Indian  ...
# 646                    Ice Cream, Desserts, Continental  ...
# 647         North Indian, Continental, Mexican, Italian  ...
# 648                 Pizza, Italian, Beverages, Desserts  ...
# 649                                      Pizza, Italian  ...
# 650                         Cafe, Continental, Desserts  ...
# 651   North Indian, Cafe, Italian, Mexican, Continental  ...
# 652      North Indian, South Indian, Asian, Continental  ...
# 653                                 Desserts, Ice Cream  ...
# ...                                                 ...  ...
# 9246                                 North Indian, Cafe  ...
# 9247                                            Chinese  ...
# 9248                            North Indian, Fast Food  ...
# 9249                              North Indian, Mughlai  ...
# 9250                    Cafe, North Indian, Continental  ...
# 9251                              North Indian, Mughlai  ...
# 9252        Japanese, American, North Indian, Fast Food  ...
# 9253                        Cafe, North Indian, Chinese  ...
# 9254                              Chinese, North Indian  ...
# 9255                              Chinese, North Indian  ...
# 9256                                   Pizza, Fast Food  ...
# 9257                                   Pizza, Fast Food  ...
# 9258                         South Indian, North Indian  ...
# 9259  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...  ...
# 9260                          Continental, North Indian  ...
# 9261                              North Indian, Biryani  ...
# 9262               North Indian, Chinese, Mediterranean  ...
# 9263                          Cafe, Fast Food, American  ...
# 9264                                          Fast Food  ...
# 9265    Andhra, North Indian, Chinese, Seafood, Biryani  ...
# 9266                      Andhra, North Indian, Chinese  ...
# 9267                 Mughlai, Chinese, Cafe, BBQ, Cajun  ...
# 9268                                          Fast Food  ...
# 9269  South Indian, Chinese, Continental, Italian, N...  ...
# 9270                                    Biryani, Andhra  ...
# 9271  Continental, Seafood, Chinese, North Indian, B...  ...
# 9272                        Cafe, North Indian, Chinese  ...
# 9273                             Burger, Pizza, Biryani  ...
# 9274          American, North Indian, Thai, Continental  ...
# 9275                                            Italian  ...
#
#                 Currency Has Table booking Has Online delivery  \
# 624   Indian Rupees(Rs.)                No                  No
# 625   Indian Rupees(Rs.)                No                  No
# 626   Indian Rupees(Rs.)                No                  No
# 627   Indian Rupees(Rs.)                No                  No
# 8021       18492065         Alam Biryani Center             1  New Delhi
# 8022         310480             Bismillah Hotel             1  New Delhi
# 8023       18144471            Halal Pizza Star             1  New Delhi
# 8024       18466972                  HTW Bakers             1  New Delhi
# 8025       18429376   Javed Bawarchi Restaurant             1  New Delhi
# 8026       18354968                   Let's Eat             1  New Delhi
# 8027       18441542                 Moonis Kada             1  New Delhi
# 8028       18445274                Motu N Patlu             1  New Delhi
# 8029       18168147              S.K. Fast Food             1  New Delhi
# 8030       18429375          Sufiyan Restaurant             1  New Delhi
# 8031         310479             The Relax Point             1  New Delhi
# 8032       18212160        Zareen's Dastarkhwan             1  New Delhi
#
#                                                 Address  \
# 2560                              Aaya Nagar, New Delhi
# 2561        84, Near Honda Showroom, Adchini, New Delhi
# 2562  81/3, 1st Floor, Qutub Residency, Adchini, New...
# 2563  66 A, Ground Floor, Sri Aurobindo Marg, Adchin...
# 2564  84, Adjacent Hero Motor Bike Showroom, Main Me...
# 2565      A- 96, Shri Aurbindo Marg, Adchini, New Delhi
# 2566                           88/3, Adchini, New Delhi
# 2567                           88/4, Adchini, New Delhi
# 2568             Sri Aurobindo Marg, Adchini, New Delhi
# 2569         A-4, Sarvodaya Enclave, Adchini, New Delhi
# 2570                  84, Main Road, Adchini, New Delhi
# 2571             84, Aurobindo Marg, Adchini, New Delhi
# 2572                  A-4, 3rd Foor, Adchini, New Delhi
# 2573                         94-A/B, Adchini, New Delhi
# 2574  Aditya Mall, Next to Cross River Mall, CBD, Ka...
# 2575  Shop SG 40, Aditya Mega Mall, Karkardooma, New...
# 2576  15/16/16-A, Plot 9-D, Aditya Mega Mall, Karkar...
# 2577  31-BC, Ground Floor, Aditya Mega Mall, Karkard...
# 2578  Ground Floor, MLCP, IGI Terminal 3, Aerocity, ...
# 2579  Red Fox Hotel, Asset 6, Aerocity Hospitality D...
# 2580  Multilevel Car Parking, Terminal 3, Aerocity, ...
# 2581  Basement, MLCP Parking, Terminal 3, Aerocity, ...
# 2582  112, Aggarwal City Mall, Road 44, Near M2K Mul...
# 2583  Shop 31, Aggarwal City Mall, Near Chunmun Stor...
# 2584  214-215, 2nd Floor, Aggarwal City Mall, Pitamp...
# 2585  G-71 & G-87, Aggarwal City Plaza, Mangalam Pal...
# 2586  G-89-90, Near M2K Cinemas, Aggarwal City Plaza...
# 2587  17, Mangalam Place, Aggarwal City Plaza, Rohin...
# 2588  G-97, Aggarwal City Plaza, Manglam Place, Rohi...
# 2589  Shop 95, Aggarwal City Plaza, Near M2K, Rohini...
# ...                                                 ...
# 8003  50/8, 1st Floor, Main Market, Yusuf Sarai, New...
# 8004  9, Community Centre, Near Green Park Metro Sta...
# 8005             5, Main Market, Yusuf Sarai, New Delhi
# 8006  42, Gautam Nagar, Behind Father Agnel School, ...
# 8007  47/3, Yusuf Sarai Main Market, Yusuf Sarai, Ne...
# 8008  10, DDA Community Centre Market, Yusuf Sarai, ...
# 8009   60/5, Yusuf Sarai Market, Yusuf Sarai, New Delhi
# 8010        95-1/2 Gautam Nagar, Yusuf Sarai, New Delhi
# 8011  F-130/4, Gautam Nagar, Sudershan Road, Yusuf S...
# 8012  G-10, Rajeshdeep Building, Yusuf Sarai, New Delhi
# 8013        74/4, Aurbindo Marg, Yusuf Sarai, New Delhi
# 8014         Shop 2, DDA Market, Yusuf Sarai, New Delhi
# 8015                       59/2, Yusuf Sarai, New Delhi
# 8016      73, Gautam Nagar Road, Yusuf Sarai, New Delhi
# 8017  Near Gate 1, Green Park Metro Station, Yusuf S...
# 8018  D65/2, Gautam Nagar, New Delhi, Yusuf Sarai, N...
# 8019         Shop 14, Main Road, Zakir Nagar, New Delhi
# 8020  K-65, Chinar Apartment, Jamia Nagar, Near Zaki...
# 8021                  Street 18, Zakir Nagar, New Delhi
# 8022           Masjid Wali Gali, Zakir Nagar, New Delhi
# 8023          88-A/4, Main Road, Zakir Nagar, New Delhi
# 8024  128, Zakir Nagar Main Road, Jogabai Extension,...
# 8025             392, Near SBI, Main Road , Zakir Nagar
# 8026  Basement, Shop 6, 88-A, Radheed Hotel Market, ...
# 8027  413, Shop B-41, Main Road, Batla House Near Ja...
# 8028  Batla House Chowk, Near Jamia Milia Islamia, O...
# 8029  161/32, Shop 3 Joga Bai, Main Road, Zakir Naga...
# 8030           57/12, Main Road, Zakir Nagar, New Delhi
# 8031                      92/17, Zakir Nagar, New Delhi
# 8032                Jamia Nagar, Zakir Nagar, New Delhi
#
#                            Locality                          Locality Verbose  \
# 2560                     Aaya Nagar                     Aaya Nagar, New Delhi
# 2561                        Adchini                        Adchini, New Delhi
# 2562                        Adchini                        Adchini, New Delhi
# 2563                        Adchini                        Adchini, New Delhi
# 2564                        Adchini                        Adchini, New Delhi
# 2565                        Adchini                        Adchini, New Delhi
# 2566                        Adchini                        Adchini, New Delhi
# 2567                        Adchini                        Adchini, New Delhi
# 2568                        Adchini                        Adchini, New Delhi
# 2569                        Adchini                        Adchini, New Delhi
# 2570                        Adchini                        Adchini, New Delhi
# 2571                        Adchini                        Adchini, New Delhi
# 2572                        Adchini                        Adchini, New Delhi
# 2573                        Adchini                        Adchini, New Delhi
# 2574  Aditya Mega Mall, Karkardooma  Aditya Mega Mall, Karkardooma, New Delhi
# 2575  Aditya Mega Mall, Karkardooma  Aditya Mega Mall, Karkardooma, New Delhi
# 2576  Aditya Mega Mall, Karkardooma  Aditya Mega Mall, Karkardooma, New Delhi
# 2577  Aditya Mega Mall, Karkardooma  Aditya Mega Mall, Karkardooma, New Delhi
# 2578                       Aerocity                       Aerocity, New Delhi
# 2579                       Aerocity                       Aerocity, New Delhi
# 2580                       Aerocity                       Aerocity, New Delhi
# 2581                       Aerocity                       Aerocity, New Delhi
# 2582  Aggarwal City Mall, Pitampura  Aggarwal City Mall, Pitampura, New Delhi
# 2583  Aggarwal City Mall, Pitampura  Aggarwal City Mall, Pitampura, New Delhi
# 2584  Aggarwal City Mall, Pitampura  Aggarwal City Mall, Pitampura, New Delhi
# 2585    Aggarwal City Plaza, Rohini    Aggarwal City Plaza, Rohini, New Delhi
# 2586    Aggarwal City Plaza, Rohini    Aggarwal City Plaza, Rohini, New Delhi
# 2587    Aggarwal City Plaza, Rohini    Aggarwal City Plaza, Rohini, New Delhi
# 2588    Aggarwal City Plaza, Rohini    Aggarwal City Plaza, Rohini, New Delhi
# 2589    Aggarwal City Plaza, Rohini    Aggarwal City Plaza, Rohini, New Delhi
# ...                             ...                                       ...
# 8003                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8004                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8005                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8006                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8007                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8008                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8009                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8010                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8011                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8012                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8013                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8014                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8015                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8016                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8017                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8018                    Yusuf Sarai                    Yusuf Sarai, New Delhi
# 8019                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8020                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8021                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8022                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8023                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8024                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8025                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8026                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8027                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8028                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8029                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8030                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8031                    Zakir Nagar                    Zakir Nagar, New Delhi
# 8032                    Zakir Nagar                    Zakir Nagar, New Delhi
#
#       Longitude   Latitude                                           Cuisines  \
# 2560   0.000000   0.000000                                     Cuisine Varies
# 2561  77.196923  28.535382                                          Fast Food
# 2562  77.197475  28.535493                 North Indian, Seafood, Continental
# 2563  77.198033  28.537547                         South Indian, North Indian
# 2564  77.196924  28.535523                South Indian, North Indian, Chinese
# 2565  77.198122  28.538134                                            Mughlai
# 2566  77.198159  28.537448                                          Fast Food
# 2567  77.197950  28.537474                                       South Indian
# 2568  77.198042  28.538394                                              Pizza
# 2569  77.198808  28.538666                              North Indian, Chinese
# 2570  77.196967  28.535763                              Chinese, North Indian
# 2571  77.196792  28.535655                             Mediterranean, Italian
# 2572  77.199152  28.538438   Continental, Seafood, Goan, Andhra, Kerala, Thai
# 2564                No                   No           2               3.4
# 2565                No                   No           1               3.1
# 2566                No                   No           1               2.7
# 2567                No                   No           1               2.6
# 2568                No                   No           1               3.7
# 2569                No                   No           3               3.5
# 2570                No                   No           2               2.2
# 2571                No                   No           3               4.0
# 2572                No                   No           3               4.2
# 2573                No                   No           3               4.2
# 2574                No                   No           2               3.2
# 2575                No                   No           2               3.4
# 2576                No                   No           2               2.8
# 2577                No                   No           3               3.7
# 2578                No                   No           2               3.2
# 2579                No                   No           2               3.2
# 2580                No                   No           2               0.0
# 2581                No                   No           2               0.0
# 2582                No                   No           3               2.6
# 2583                No                   No           1               3.3
# 2584                No                   No           3               3.2
# 2585                No                   No           1               3.4
# 2586                No                   No           2               3.3
# 2587                No                   No           3               2.6
# 2588                No                   No           1               3.7
# 2589                No                   No           2               2.2
# ...                ...                  ...         ...               ...
# 8003                No                   No           3               3.0
# 8004                No                   No           1               2.7
# 8005                No                   No           1               3.2
# 8006                No                   No           1               2.7
# 8007                No                   No           1               3.0
# 8008                No                   No           1               3.9
# 8009                No                   No           2               3.7
# 8010                No                   No           1               0.0
# 8011                No                   No           1               0.0
# 8012                No                   No           1               0.0
# 8013                No                   No           1               0.0
# 8014                No                   No           1               0.0
# 8015                No                   No           1               0.0
# 8016                No                   No           1               0.0
# 8017                No                   No           1               0.0
# 8018                No                   No           1               0.0
# 8019                No                   No           1               0.0
# 8020                No                   No           1               0.0
# 8021                No                   No           1               0.0
# 8022                No                   No           1               0.0
# 8023                No                   No           1               0.0
# 8024                No                   No           1               0.0
# 8025                No                   No           2               0.0
# 8026                No                   No           1               0.0
# 8027                No                   No           2               0.0
# 8028                No                   No           1               0.0
# 8029                No                   No           1               0.0
# 8030                No                   No           1               0.0
# 8031                No                   No           1               0.0
# 8032                No                   No           2               0.0
#
#       Rating color Rating text Votes
# 2560         White   Not rated     2
# 2561        Orange     Average    46
# 2562        Orange     Average    45
# 2563        Orange     Average    11
# 2564        Orange     Average   238
# 2565        Orange     Average     8
# 2566        Orange     Average    64
# 2567        Orange     Average   113
# 2568        Yellow        Good    66
# 2569        Yellow        Good   141
# 2570           Red        Poor    77
# 2571         Green   Very Good    40
# 2572         Green   Very Good    46
# 2573         Green   Very Good   665
# 2574        Orange     Average    31
# 2575        Orange     Average    32
# 2576        Orange     Average    83
# 2577        Yellow        Good   288
# 2578        Orange     Average    33
# 2579        Orange     Average    26
# 2580         White   Not rated     2
# 2581         White   Not rated     0
# 2582        Orange     Average    49
# 2583        Orange     Average    13
# 2584        Orange     Average    64
# 2585        Orange     Average   167
# 2586        Orange     Average    99
# 2587        Orange     Average   125
# 2588        Yellow        Good   124
# 2589           Red        Poor    79
# ...            ...         ...   ...
# 8003        Orange     Average    42
# 8004        Orange     Average   128
# 8005        Orange     Average    30
# 8006        Orange     Average     8
# 8007        Orange     Average    25
# 8008        Yellow        Good   109
# 8009        Yellow        Good   334
# 8010         White   Not rated     2
# 8011         White   Not rated     3
# 8012         White   Not rated     0
# 8013         White   Not rated     0
# 8014         White   Not rated     1
# 9273        2800881                                Plot 17             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#               City                                            Address  \
# 628           Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...
# 630           Agra          ITC Mughal, Fatehabad Road, Tajganj, Agra
# 637           Agra  Opposite The Gateway Hotel, Fatehabad Road, Ta...
# 641           Agra  8, Handicraft Nagar, Fatehabad Road, Tajganj, ...
# 642           Agra  Near Purani Mandi Crossing,Fatehabad Road, Taj...
# 644      Ahmedabad  Shreekunj Mandapam, Beside Golden Tulip Bunglo...
# 646      Ahmedabad  7 B, Circle  B, Opposite Rajpath Club, Sarkhej...
# 648      Ahmedabad  Ground Floor, Maruti Crystal, Opposite Rajpath...
# 649      Ahmedabad  Shop 10,  Circle B, Nyay Marg, Bodakdev, Ahmed...
# 650      Ahmedabad  6-9, Ground Floor, Devashish Business Park, Op...
# 653      Ahmedabad  Ground Floor, Arjun Avenue, Opposite Samarthes...
# 654      Ahmedabad           Near Law Garden, Ellis Bridge, Ahmedabad
# 655      Ahmedabad  At Five Petals Hotel & Banquets, Near Chanakya...
# 657      Ahmedabad  103, Kairos, Opposite Mahatma Gandhi Labour In...
# 659      Ahmedabad  34, Shribhuvan Complex, Near Memnagar Fire Sta...
# 660      Ahmedabad  12, First Floor, Camps Corner 2, Opposite Prah...
# 727      Bangalore  610, 3rd Floor, 12th Main, Off 80 Feet Road, I...
# 728      Bangalore  298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# 730      Bangalore  2989/B, 12th Main Road, HAL 2nd Stage, Indiran...
# 732      Bangalore  501, Binnamangala Extension, 1st stage, C.M.H ...
# 733      Bangalore  Site 15, 15th Cross, 100 Feet Road, 4th Phase,...
# 734      Bangalore  44, 4th B Cross, Koramangala 5th Block, Bangalore
# 735      Bangalore  28, 4th 'B' Cross, Koramangala 5th Block, Bang...
# 737      Bangalore  11, 80 Feet Road, Opposite Indian Oil Petrol P...
# 738      Bangalore  118, Koramangala Industrial Area, Koramangala ...
# 739      Bangalore  90/4, 3rd Floor, Outer Ring Road, Munnekollaly...
# 740      Bangalore  9/1, 1st Floor, Above Surya Nissan, VRR Orchid...
# 741      Bangalore  215, 216 & 220, Devasandra Village, Kasaba Hob...
# 742      Bangalore  67 & 68, Brigade Solitaire, Opposite to Advait...
# 743      Bangalore  Behind MK Retail, Before WIPRO Corporate Offic...
# ...            ...                                                ...
# 9156          Pune  4, Deron Heights, Next to Ranka Jewellers, Ban...
# 9157          Pune  759/125, Rajkamal, Opposite Kelkar Eye Hospita...
# 9158          Pune  Level 1 & 2, Fortaleza Complex, East Avenue, K...
# 9159          Pune  Level 1/2, Fortaleza Complex, Kalyani Nagar, Pune
# 9161          Pune          End of Lane Number 6, Koregaon Park, Pune
# 9162          Pune  Shop 1&2, Marvel Alaina, Lane  8, Near Godrej ...
# 9163          Pune  Plot 5, Between Lane 5/6, North Main Road, Opp...
# 9166          Pune  UG 49, Phoenix Market City, Nagar Road, Viman ...
# 9167          Pune  3rd Floor, R Deccan Mall, Near Deccan Gymkhana...
# 9168          Pune  Punawale, Near Basket Bridge,Off Aundh-Ravet B...
# 9169          Pune  Terrace, B Wing, ICC Trade Tower, Senapati Bap...
# 9173          Pune  257, Green Valley, Near Mankar Chowk, Kaspate ...
# 9194  Secunderabad      The Purple Leaf Hotel, Karkhana, Secunderabad
# 9195  Secunderabad  E 89, Above Canara Bank, Sainikpuri, Secunderabad
# 9200         Surat  10-15, Second Floor, Rangila Park, Ghod Dod Ro...
# 9203         Surat  LG-5/6/19, Megh Mayur Plaza, Parle Point, Sura...
# 9206         Surat  Ground Floor, International Business Centre, S...
# 9216      Vadodara  1st Floor, Tapan Complex, Next To M Cube Mall,...
# 9220      Vadodara  3rd Floor, Shreem Shalini Mall, R.C. Dutt Road...
# 9223      Vadodara           33, Sampatrao Colony, Alkapuri, Vadodara
# 9228      Vadodara  1, Trivia, Natu Bhai Circle, Race Course Road,...
# 9232      Vadodara  1-8, Opposite INOX Multiplex, Sharnam Fortune,...
# 9233      Vadodara  Shop 2-3, Ground Floor, Opposite Natubhai Circ...
# 9256         Vizag  52-1-35,36&38, CMR Mall, New Resapavanipalem, ...
# 9257         Vizag  Plot No 47- 10-23/3, 5th Floor, Isnar Khazana ...
# 9258         Vizag  Diamond Park, Railway New Colony Road, Dwaraka...
# 9259         Vizag  Hotel GreenPark, Waltair Main Road, Waltair Up...
# 9262         Vizag  1st Floor, ATR Towers, Harbour Park Road,  Pan...
# 9273         Vizag         Plot 17, Gangapur Layout, Siripuram, Vizag
# 9275         Vizag  10-50-12/F2, Sai Dakshata Complex, Beside Leno...
#
#                                    Locality  \
# 628                             Civil Lines
# 630                     ITC Mughal, Tajganj
# 637                                 Tajganj
# 641                                 Tajganj
# 642                                 Tajganj
# 644                                Ambavadi
# 646                                Bodakdev
# 648                                Bodakdev
# 649                                Bodakdev
# 650                                Bodakdev
# 653                            Ellis Bridge
# 654                            Ellis Bridge
# 655                               Ghatlodia
# 657                                 Gurukul
# 659                             Navrangpura
# 660                           Prahlad Nagar
# 727                             Indiranagar
# 728                             Indiranagar
# 730                             Indiranagar
# 732                             Indiranagar
# 733                                JP Nagar
# 734                   Koramangala 5th Block
# 735                   Koramangala 5th Block
# 737                   Koramangala 6th Block
# 738                   Koramangala 7th Block
# 739                            Marathahalli
# 740                            Marathahalli
# 741                            New BEL Road
# 742                          Residency Road
# 743                           Sarjapur Road
# ...                                     ...
# 9156                                  Baner
# 9157                        Deccan Gymkhana
# 9158                          Kalyani Nagar
# 9159                          Kalyani Nagar
# 9161                          Koregaon Park
# 9162                          Koregaon Park
# 9163                          Koregaon Park
# 9166       Phoenix Market City, Viman Nagar
# 9167                 R Deccan Mall, JM Road
# 9168                                  Ravet
# 9169                    Senapati Bapat Road
# 9173                                  Wakad
# 9194                               Karkhana
# 9195                             Sainikpuri
# 9200                                  Athwa
# 9203                             City Light
# 9206  International Business Center, Piplod
# 9216                               Alkapuri
# 9220                               Alkapuri
# 9223                               Alkapuri
# 9203                             City Light, Surat  72.792731  21.173343
# 9206  International Business Center, Piplod, Surat  72.768778  21.157735
# 9216                            Alkapuri, Vadodara  73.167788  22.307898
# 9220                            Alkapuri, Vadodara  73.170937  22.310526
# 9223                            Alkapuri, Vadodara   0.000000   0.000000
# 9228                            Vadiwadi, Vadodara  73.158921  22.310237
# 9232                            Vadiwadi, Vadodara   0.000000   0.000000
# 9233                            Vadiwadi, Vadodara   0.000000   0.000000
# 9256         CMR Central Mall, Maddilapalem, Vizag  83.318511  17.734178
# 9257                          Dwaraka Nagar, Vizag  83.305139  17.726147
# 9258                          Dwaraka Nagar, Vizag  83.303414  17.726297
# 9259                 Hotel GreenPark, Vizag, Vizag  83.307073  17.715819
# 9262                      Kirlampudi Layout, Vizag   0.000000   0.000000
# 9273                              Siripuram, Vizag  83.315281  17.719539
# 9275                        Waltair Uplands, Vizag  83.314942  17.721119
#
#                                                Cuisines  ...    \
# 628                      North Indian, Chinese, Mughlai  ...
# 630                               North Indian, Mughlai  ...
# 637                         Cafe, North Indian, Chinese  ...
# 641                                      Italian, Pizza  ...
# 642         Chinese, Italian, Continental, North Indian  ...
# 644   Chinese, Italian, North Indian, Mexican, Medit...  ...
# 646                    Ice Cream, Desserts, Continental  ...
# 648                 Pizza, Italian, Beverages, Desserts  ...
# 649                                      Pizza, Italian  ...
# 650                         Cafe, Continental, Desserts  ...
# 653                                 Desserts, Ice Cream  ...
# 654                Fast Food, Street Food, South Indian  ...
# 655                  North Indian, Chinese, Continental  ...
# 657                                  Italian, Fast Food  ...
# 659                                       Cafe, Italian  ...
# 660   North Indian, Continental, Beverages, Italian,...  ...
# 727                                               Asian  ...
# 728                            Italian, American, Pizza  ...
# 730                                       Modern Indian  ...
# 732                                Pizza, Cafe, Italian  ...
# 733                                Pizza, Cafe, Italian  ...
# 734   Continental, American, Italian, North Indian, ...  ...
# 735                              American, Burger, Cafe  ...
# 737   North Indian, Chinese, Italian, Street Food, D...  ...
# 738                               Continental, American  ...
# 739               European, Mediterranean, North Indian  ...
# 740                  Asian, Mediterranean, North Indian  ...
# 741                                Pizza, Cafe, Italian  ...
# 742                                         Continental  ...
# 743   Finger Food, North Indian, Italian, Continenta...  ...
# ...                                                 ...  ...
# 9156        Continental, North Indian, Mughlai, Burmese  ...
# 9157                                 European, Desserts  ...
# 9158                                      Modern Indian  ...
# 9159           North Indian, North Eastern, Continental  ...
# 9161        Continental, North Indian, Mughlai, Burmese  ...
# 9162  Charcoal Grill, Italian, North Indian, Europea...  ...
# 9163                         Cafe, Italian, Continental  ...
# 9166                         Mexican, American, Tex-Mex  ...
# 9167                              North Indian, Mughlai  ...
# 9168                 North Indian, Chinese, Continental  ...
# 9169                 Continental, North Indian, Italian  ...
# 9173                                       North Indian  ...
# 9194                              North Indian, Chinese  ...
# 9195                                  Cafe, Continental  ...
# 9200                                            Chinese  ...
# 9203                                  Lebanese, Italian  ...
# 9206                    Italian, Mexican, Mediterranean  ...
# 9216                                       South Indian  ...
# 9220                              Mughlai, North Indian  ...
# 732          Green   Very Good   1413
# 733     Dark Green   Excellent    781
# 734     Dark Green   Excellent    276
# 735     Dark Green   Excellent   9667
# 737          Green   Very Good    753
# 738     Dark Green   Excellent   1288
# 739     Dark Green   Excellent   6907
# 740          Green   Very Good    983
# 741     Dark Green   Excellent    627
# 742          Green   Very Good    334
# 743     Dark Green   Excellent   5705
# ...            ...         ...    ...
# 9156         Green   Very Good    375
# 9157    Dark Green   Excellent   2510
# 9158         Green   Very Good    868
# 9159         Green   Very Good    306
# 9161         Green   Very Good   1531
# 9162         Green   Very Good    635
# 9163         Green   Very Good    583
# 9166    Dark Green   Excellent   1439
# 9167    Dark Green   Excellent   2847
# 9168         Green   Very Good    487
# 9169         Green   Very Good   1531
# 9173         Green   Very Good    208
# 9194         Green   Very Good    494
# 9195    Dark Green   Excellent   1408
# 9200         Green   Very Good    197
# 9203         Green   Very Good    479
# 9206         Green   Very Good    319
# 9216    Dark Green   Excellent    344
# 9220         Green   Very Good    332
# 9223         Green   Very Good    276
# 9228    Dark Green   Excellent    321
# 9232         Green   Very Good     92
# 9233         Green   Very Good    132
# 9256    Dark Green   Excellent    289
# 9257         Green   Very Good    230
# 9258         Green   Very Good    270
# 9259         Green   Very Good     73
# 9262    Dark Green   Excellent    345
# 9273         Green   Very Good    172
# 9275         Green   Very Good    316
#
# [430 rows x 21 columns]

# %%
zomato.iloc[0]
# Out:
# Restaurant ID                                                     6317637
# Restaurant Name                                          Le Petit Souffle
# Country Code                                                          162
# City                                                          Makati City
# Address                 Third Floor, Century City Mall, Kalayaan Avenu...
# Locality                        Century City Mall, Poblacion, Makati City
# Locality Verbose        Century City Mall, Poblacion, Makati City, Mak...
# Longitude                                                         121.028
# Latitude                                                          14.5654
# Cuisines                                       French, Japanese, Desserts
# Average Cost for two                                                 1100
# Currency                                                 Botswana Pula(P)
# Has Table booking                                                     Yes
# Has Online delivery                                                    No
# Is delivering now                                                      No
# Switch to order menu                                                   No
# Price range                                                             3
# Aggregate rating                                                      4.8
# Rating color                                                   Dark Green
# Rating text                                                     Excellent
# Votes                                                                 314
# Name: 0, dtype: object

# %%
zomato.shape
# Out:
# (9551, 21)

# %%
## Type of cities in dataset
cities = zomato['City'].unique()
cities
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Brasí_lia', 'Rio de Janeiro', 'Sí£o Paulo',
#        'Albany', 'Armidale', 'Athens', 'Augusta', 'Balingup',
#        'Beechworth', 'Boise', 'Cedar Rapids/Iowa City', 'Chatham-Kent',
#        'Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
#        'Davenport', 'Des Moines', 'Dicky Beach', 'Dubuque',
#        'East Ballina', 'Fernley', 'Flaxton', 'Forrest', 'Gainesville',
#        'Hepburn Springs', 'Huskisson', 'Inverloch', 'Lakes Entrance',
#        'Lakeview', 'Lincoln', 'Lorn', 'Macedon', 'Macon', 'Mayfield',
#        'Mc Millan', 'Middleton Beach', 'Miller', 'Monroe', 'Montville',
#        'Ojo Caliente', 'Orlando', 'Palm Cove', 'Paynesville', 'Penola',
#        'Pensacola', 'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
#        'Tampa Bay', 'Tanunda', 'Trentham East', 'Valdosta', 'Vernonia',
#        'Victor Harbor', 'Vineland Station', 'Waterloo', 'Weirton',
#        'Winchester Bay', 'Yorkton', 'Abu Dhabi', 'Dubai', 'Sharjah',
#        'Agra', 'Ahmedabad', 'Allahabad', 'Amritsar', 'Aurangabad',
#        'Bangalore', 'Bhopal', 'Bhubaneshwar', 'Chandigarh', 'Chennai',
#        'Coimbatore', 'Dehradun', 'Faridabad', 'Ghaziabad', 'Goa',
#        'Gurgaon', 'Guwahati', 'Hyderabad', 'Indore', 'Jaipur', 'Kanpur',
#        'Kochi', 'Kolkata', 'Lucknow', 'Ludhiana', 'Mangalore', 'Mohali',
#        'Mumbai', 'Mysore', 'Nagpur', 'Nashik', 'New Delhi', 'Noida',
#        'Panchkula', 'Patna', 'Puducherry', 'Pune', 'Ranchi',
#        'Secunderabad', 'Surat', 'Vadodara', 'Varanasi', 'Vizag',
#        'Bandung', 'Bogor', 'Jakarta', 'Tangerang', 'Auckland',
#        'Wellington City', 'Birmingham', 'Edinburgh', 'London',
#        'Manchester', 'Doha', 'Cape Town', 'Inner City', 'Johannesburg',
#        'Pretoria', 'Randburg', 'Sandton', 'Colombo', 'Ankara',
#        'ÛÁstanbul'], dtype=object)

# %%
## Type of cuisines in the dataset
clb.cuisine_bag
# Out:
# ['finger food',
#  'street food',
#  'indian',
#  'nepalese',
#  'teriyaki',
#  'burmese',
#  'belgian',
#  'afghani',
#  'gourmet fast food',
#  'moroccan',
#  'filipino',
#  'cuban',
#  'indonesian',
#  'goan',
#  'healthy food',
#  'mithai',
#  'maharashtrian',
#  'peranakan',
#  'gujarati',
#  'cafe',
#  'peruvian',
#  'seafood',
#  'bar food',
#  'beverages',
#  'brazilian',
#  'biryani',
#  'drinks only',
#  'european',
#  'north indian',
#  'german',
#  'british',
#  'kashmiri',
#  'italian',
#  'burger',
#  'asian fusion',
#  'charcoal grill',
#  'caribbean',
#  'dim sum',
#  'cuisine varies',
#  'breakfast',
#  'naga',
#  'mediterranean',
#  'coffee and tea',
#  'hawaiian',
#  'sushi',
#  'salad',
#  'fish and chips',
#  'raw meats',
#  'chinese',
#  'malwani',
#  'tapas',
#  'restaurant cafe',
#  'latin american',
#  'mangalorean',
#  'sandwich',
#  'fast food',
#  'japanese',
#  'bubble tea',
#  'patisserie',
#  'greek',
#  'fusion',
#  'ice cream',
#  'western',
#  'singaporean',
#  'spanish',
#  'american',
#  'kebab',
#  'soul food',
#  'izgara',
#  'parsi',
#  'sunda',
#  'pizza',
#  'contemporary',
#  'tea',
#  'south african',
#  'bí_rek',
#  'malay',
#  'south american',
#  'sri lankan',
#  'desserts',
#  'australian',
#  'korean',
#  'cajun',
#  'durban',
#  'irish',
#  'kerala',
#  'scottish',
#  'new american',
#  'hyderabadi',
#  'continental',
#  'deli',
#  'oriya',
#  'middle eastern',
#  'steak',
#  'vietnamese',
#  'arabian',
#  'bihari',
#  'mexican',
#  'turkish',
#  'tibetan',
#  'tex-mex',
#  'curry',
#  'thai',
#  'juices',
#  'ramen',
#  'grill',
#  'canadian',
#  'south indian',
#  'international',
#  'modern australian',
#  'vegetarian',
#  'persian',
#  'armenian',
#  'bbq',
#  'taiwanese',
#  'north eastern',
#  'malaysian',
#  'assamese',
#  'turkish pizza',
#  'pub food',
#  'asian',
#  'southern',
#  'mineira',
#  'modern indian',
#  'portuguese',
#  'southwestern',
#  'kiwi',
#  'world cuisine',
#  'dí_ner',
#  'bengali',
#  'french',
#  'lebanese',
#  'mughlai',
#  'bakery',
#  'chettinad',
#  'andhra',
#  'awadhi',
#  'pakistani',
#  'lucknowi',
#  'cantonese',
#  'argentine',
#  'diner',
#  'african',
#  'rajasthani',
#  'iranian']

# %%
# Has Online Booking type 
clb.dataset['Has Online delivery'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Has Table Booking type 
clb.dataset['Has Table booking'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
clb.dataset['Rating text'].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %%
clb.dataset['Rating color'].unique()
# Out:
# array(['Dark Green', 'Green', 'Yellow', 'Orange', 'White', 'Red'],
#       dtype=object)

# %%
filter_data(country = 'india', cuisine = 'gujarati', rating = 4, price_min_rate= 3, price_max_rate= 890)
# Out:
# Reading data from zomato.csv
# india
# 1
# ['gujarati']
# gujarati
# Reading data from zomato.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-244c439dd939> in <module>
# ----> 1 filter_data(country = 'india', cuisine = 'gujarati', rating = 4, price_min_rate= 3, price_max_rate= 890)
#
# <ipython-input-40-29185f9b326b> in filter_data(country, city, cuisine, rating, price_min_rate, price_max_rate, table_book, online_order)
#       9     else:
#      10         data = clb.dataset
# ---> 11     data = clb.filter_cuisine(cuisine, data)
#      12     data = clb.filter_online_delivery(data, online_order)
#      13     data = clb.filter_table_booking(data, table_book)
#
# <ipython-input-26-c940dd7b8078> in filter_cuisine(self, cuisine_list, dataset)
#      99         for l in cuisine_list:
#     100             print (l)
# --> 101             bag.extend([x for x in filter(lambda x: l in x, self.cuisine_bag)])
#     102         bag_exp = '|'.join([x for x in bag])
#     103         bag_exp = '(' + bag_exp + ')'
#
# <ipython-input-27-ea463a323e1f> in filter(country, city, cuisine, rating, price_min_rate, price_max_rate, table_book, online_order)
#       4     data = None
#       5     if country != None:
# ----> 6         data = clb.country_filter(country)
#       7     elif city != None:
#       8         data = clb.filter_city(city)
#
# <ipython-input-26-c940dd7b8078> in country_filter(self, country)
#      50     def country_filter(self, country):
#      51         if type(country) != str:
# ---> 52             raise(TypeError('Country Name is a string'))
#      53         code = self.countryCode[self.countryCode['country'] == country.lower()]['code'][0]
#      54         print (code)
#
# TypeError: Country Name is a string

# %%
clb.country_filter('india')
# Out:
# 627        Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...
# 628        Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...
# 629        Agra  Courtyard by Marriott Agra, Phase 2, Fatehabad...
# 630        Agra          ITC Mughal, Fatehabad Road, Tajganj, Agra
# 631        Agra          ITC Mughal, Fatehabad Road, Tajganj, Agra
# 632        Agra  3/20, KPS Tower, Near Tulsi Talkies, Bypass Ro...
# 633        Agra    Radisson Blu, Taj East Gate Road, Tajganj, Agra
# 634        Agra    Radisson Blu, Taj East Gate Road, Tajganj, Agra
# 635        Agra  Meher Cinema Complex, Gwalior Road, Rakabganj,...
# 636        Agra       Hotel Samovar, Fatehabad Road, Tajganj, Agra
# 637        Agra  Opposite The Gateway Hotel, Fatehabad Road, Ta...
# 638        Agra  Parador Hotel, 3A-3B, Phase 1, Fatehabad Road,...
# 639        Agra  1374 K/1375 K, 2nd floor, Dinesh Nagar, Fatehb...
# 640        Agra  Opposite Saga Emporium, Fatehabad Road, Tajgan...
# 641        Agra  8, Handicraft Nagar, Fatehabad Road, Tajganj, ...
# 642        Agra  Near Purani Mandi Crossing,Fatehabad Road, Taj...
# 643        Agra  Next To ITC Mughal Hotel, Fatehabad Road, Tajg...
# 644   Ahmedabad  Shreekunj Mandapam, Beside Golden Tulip Bunglo...
# 645   Ahmedabad  Chinubhai Tower, Nehru Bridge Corner, Ashram R...
# 646   Ahmedabad  7 B, Circle  B, Opposite Rajpath Club, Sarkhej...
# 647   Ahmedabad        Opposite Sindhu Bhawan, Bodakdev, Ahmedabad
# 648   Ahmedabad  Ground Floor, Maruti Crystal, Opposite Rajpath...
# 649   Ahmedabad  Shop 10,  Circle B, Nyay Marg, Bodakdev, Ahmed...
# 650   Ahmedabad  6-9, Ground Floor, Devashish Business Park, Op...
# 651   Ahmedabad  10th Floor, Balaji Heights Buliding, Behind Ta...
# 652   Ahmedabad  Courtyard By Marriott, Ramdevnagar Cross Road,...
# 653   Ahmedabad  Ground Floor, Arjun Avenue, Opposite Samarthes...
# ...         ...                                                ...
# 9246   Varanasi  1st Floor, Swastik Plaza, Near Ravidas Gate, B...
# 9247   Varanasi           34-B, Ravindra Puri, Near Lanka,Varanasi
# 9248   Varanasi  S 19/1 K, Mint House, Near Hotel Taj, Nai Baza...
# 9249   Varanasi         Near Sbi Atm, Main Road, Nadesar, Varanasi
# 9250   Varanasi   Radisson Hotel, The Mall Road, Nadesar, Varanasi
# 9251   Varanasi   Radisson Hotel, The Mall Road, Nadesar, Varanasi
# 9252   Varanasi               B 3/335, Krimkund, Shivala, Varanasi
# 9253   Varanasi  5th Floor Roof Top,(Above Big Bazaar) Sigra. O...
# 9254   Varanasi  Hotel Varuna Ground Floor, 22 Gulab Bagh, Sigr...
# 9255   Varanasi  1st Floor, Nath Complex, Beside Life Line Hosp...
# 9256      Vizag  52-1-35,36&38, CMR Mall, New Resapavanipalem, ...
# 9257      Vizag  Plot No 47- 10-23/3, 5th Floor, Isnar Khazana ...
# 9258      Vizag  Diamond Park, Railway New Colony Road, Dwaraka...
# 9259      Vizag  Hotel GreenPark, Waltair Main Road, Waltair Up...
# 9260      Vizag    Hotel Novotel, Beach Road, Maharani Peta, Vizag
# 9261      Vizag  28-10-33/6, Jagdamba Commercial Complex, Chitr...
# 9262      Vizag  1st Floor, ATR Towers, Harbour Park Road,  Pan...
# 9263      Vizag  Ground Floor, ATR Towers, Harbour Park Road, P...
# 9264      Vizag   4-70-4, Opposite NCC Canteen, Lawsons Bay, Vizag
# 9265      Vizag  Beach Road, Near Santhi Ashram, Lawsons Bay, V...
# 9266      Vizag  HB Colony, Isukathota, National Highway 5, Bes...
# 9267      Vizag  RK Beach, Maharani Peta, Vizag Visakhapatnam.,...
# 9268      Vizag  7-5-82, Sea Shore Apartments, Southern Portion...
# 9269      Vizag  1-83-29, Opposite Pollock Lotus School, MVP Do...
# 9270      Vizag  Beach Road, Opposite Cyclone Shelter ,   Visak...
# 9271      Vizag  Beach Road, Near Bus Stop, Sagar Nagar, Visakh...
# 9272      Vizag  Plot 95, Opposite St. Lukes Nursing School, Da...
# 9273      Vizag         Plot 17, Gangapur Layout, Siripuram, Vizag
# 9274      Vizag  The Park, Beach Road, Pedda Waltair, Lawsons B...
# 9275      Vizag  10-50-12/F2, Sai Dakshata Complex, Beside Leno...
#
#                                  Locality  \
# 624                            Agra Cantt
# 625                            Agra Cantt
# 626                            Agra Cantt
# 627                           Civil Lines
# 628                           Civil Lines
# 629   Courtyard by Marriott Agra, Tajganj
# 630                   ITC Mughal, Tajganj
# 631                   ITC Mughal, Tajganj
# 632                              Khandari
# 633                 Radisson Blu, Tajganj
# 634                 Radisson Blu, Tajganj
# 635                             Rakabganj
# 636                               Tajganj
# 637                               Tajganj
# 638                               Tajganj
# 639                               Tajganj
# 640                               Tajganj
# 641                               Tajganj
# 642                               Tajganj
# 643                               Tajganj
# 644                              Ambavadi
# 645                           Ashram Road
# 646                              Bodakdev
# 647                              Bodakdev
# 648                              Bodakdev
# 649                              Bodakdev
# 650                              Bodakdev
# 651                              C G Road
# 652      Courtyard By Marriott, Satellite
# 653                          Ellis Bridge
# ...                                   ...
# 9246                                Lanka
# 9247                                Lanka
# 9248                              Nadesar
# 9249                              Nadesar
# 9250              Radisson Hotel, Nadesar
# 9251              Radisson Hotel, Nadesar
# 9252                              Shivala
# 9253                                Sigra
# 9254                                Sigra
# 9255                            Sunderpur
# 9256       CMR Central Mall, Maddilapalem
# 9257                        Dwaraka Nagar
# 9258                        Dwaraka Nagar
# 9259               Hotel GreenPark, Vizag
# 9260         Hotel Novotel, Maharani Peta
# 9261                   Jagadamba Junction
# 9262                    Kirlampudi Layout
# 9263                    Kirlampudi Layout
# 9264                          Lawsons Bay
# 9265                          Lawsons Bay
# 9266                         Maddilapalem
# 9267                        Maharani Peta
# 9268                        Maharani Peta
# 9269                           MVP Colony
# 9270                           Rushikonda
# 9271                          Sagar Nagar
# 9272                            Siripuram
# 9273                            Siripuram
# 9274                The Park, Lawsons Bay
# 9265                           Lawsons Bay, Vizag  83.338097  17.734806
# 9266                          Maddilapalem, Vizag  83.326859  17.740024
# 9267                         Maharani Peta, Vizag  83.319840  17.712662
# 9268                         Maharani Peta, Vizag   0.000000   0.000000
# 9269                            MVP Colony, Vizag  83.304558  17.726709
# 9270                            Rushikonda, Vizag  83.382858  17.783869
# 9271                           Sagar Nagar, Vizag  83.361377  17.764287
# 9272                             Siripuram, Vizag   0.000000   0.000000
# 9273                             Siripuram, Vizag  83.315281  17.719539
# 9274                 The Park, Lawsons Bay, Vizag  83.336840  17.721182
# 9275                       Waltair Uplands, Vizag  83.314942  17.721119
#
#                                                Cuisines  ...   \
# 624                               North Indian, Mughlai  ...
# 625                               North Indian, Mughlai  ...
# 626                                        North Indian  ...
# 627                                          Rajasthani  ...
# 628                      North Indian, Chinese, Mughlai  ...
# 629                              North Indian, European  ...
# 630                               North Indian, Mughlai  ...
# 631                                             Mughlai  ...
# 632                       Rajasthani, Gujarati, Mughlai  ...
# 633                               North Indian, Mughlai  ...
# 634                  North Indian, Chinese, Continental  ...
# 635                              South Indian, Desserts  ...
# 636         North Indian, Chinese, Continental, Mughlai  ...
# 637                         Cafe, North Indian, Chinese  ...
# 638                  North Indian, Chinese, Continental  ...
# 639   Cafe, Italian, Mexican, North Indian, Continental  ...
# 640                               North Indian, Mughlai  ...
# 641                                      Italian, Pizza  ...
# 642         Chinese, Italian, Continental, North Indian  ...
# 643                             North Indian, Fast Food  ...
# 644   Chinese, Italian, North Indian, Mexican, Medit...  ...
# 645                  Continental, Chinese, North Indian  ...
# 646                    Ice Cream, Desserts, Continental  ...
# 647         North Indian, Continental, Mexican, Italian  ...
# 648                 Pizza, Italian, Beverages, Desserts  ...
# 649                                      Pizza, Italian  ...
# 650                         Cafe, Continental, Desserts  ...
# 651   North Indian, Cafe, Italian, Mexican, Continental  ...
# 652      North Indian, South Indian, Asian, Continental  ...
# 653                                 Desserts, Ice Cream  ...
# ...                                                 ...  ...
# 9246                                 North Indian, Cafe  ...
# 9247                                            Chinese  ...
# 9248                            North Indian, Fast Food  ...
# 9249                              North Indian, Mughlai  ...
# 9250                    Cafe, North Indian, Continental  ...
# 9251                              North Indian, Mughlai  ...
# 9252        Japanese, American, North Indian, Fast Food  ...
# 9253                        Cafe, North Indian, Chinese  ...
# 9254                              Chinese, North Indian  ...
# 9255                              Chinese, North Indian  ...
# 9256                                   Pizza, Fast Food  ...
# 9257                                   Pizza, Fast Food  ...
# 9258                         South Indian, North Indian  ...
# 9259  Chinese, Thai, Burmese, Vietnamese, Tibetan, J...  ...
# 9260                          Continental, North Indian  ...
# 9261                              North Indian, Biryani  ...
# 9262               North Indian, Chinese, Mediterranean  ...
# 9263                          Cafe, Fast Food, American  ...
# 9264                                          Fast Food  ...
# 9265    Andhra, North Indian, Chinese, Seafood, Biryani  ...
# 9266                      Andhra, North Indian, Chinese  ...
# 9267                 Mughlai, Chinese, Cafe, BBQ, Cajun  ...
# 9268                                          Fast Food  ...
# 653     Dark Green   Excellent   166
# ...            ...         ...   ...
# 9246        Orange     Average    85
# 9247        Yellow        Good   172
# 9248        Orange     Average    96
# 9249        Yellow        Good    63
# 9250        Orange     Average    34
# 9251        Orange     Average    67
# 9252        Yellow        Good    83
# 9253        Orange     Average    26
# 9254        Yellow        Good   109
# 9255        Yellow        Good    57
# 9256    Dark Green   Excellent   289
# 9257         Green   Very Good   230
# 9258         Green   Very Good   270
# 9259         Green   Very Good    73
# 9260         Green   Very Good   125
# 9261        Yellow        Good   240
# 9262    Dark Green   Excellent   345
# 9263        Yellow        Good    27
# 9264        Yellow        Good   175
# 9265        Yellow        Good   154
# 9266        Yellow        Good   124
# 9267        Yellow        Good    84
# 9268        Yellow        Good    57
# 9269         Green   Very Good    75
# 9270         Green   Very Good   169
# 9271        Yellow        Good   193
# 9272        Yellow        Good    85
# 9273         Green   Very Good   172
# 9274        Yellow        Good    74
# 9275         Green   Very Good   316
#
# [8652 rows x 21 columns]

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re


class CSVNotFoundException(Exception):
    pass


class InvalidRangeException(Exception):
    pass


class CollaborativeFilter(object):

    def __init__(self, csvPath, countryPath):
        self.dataset = self.get_data_csv(csvPath)
        self.countryCode = self.get_country_csv(countryPath)
        self.create_cuisine_bag()

    def filter_online_delivery(self, data, param):
        data = data[data['Has Online delivery'] == param]
        return data

    def filter_table_booking(self, data, param):
        data = data[data['Has Table booking'] == param]
        return data

    def filter_price_range(self, data, lower_range=1, upper_range=5):

        if (type(data) != pd.DataFrame):
            raise (TypeError('Not a dataframe'))

        if not (lower_range >= 1 and upper_range <= 5):
            raise (InvalidRangeException('only ranging from 1 to 5'))
        mask1 = data['Price range'] >= lower_range
        mask2 = data['Price range'] <= upper_range
        data = data[mask1 & mask2]
        return data

    def filter_avg_cost(self, dataset, lower_range=0, upper_range=800000):
        mask1 = data['Average Cost for two'] >= lower_range
        mask2 = data['Average Cost for two'] <= upper_range
        data = data[mask1 & mask2]
        return data

    def country_filter(self, country):
        if type(country) != str:
            raise (TypeError('Country Name is a string'))
        code = self.countryCode[self.countryCode['country'] == country.lower()]['code'][0]
        print(code)
        data = self.dataset[self.dataset['Country Code'] == code]
        return data

    def get_country_csv(self, csvPath):

        if not (os.path.exists(csvPath)):
            raise (FileNotFoundError('{} is not found'.format(csvPath)))

        if not (os.path.isfile(csvPath)):
            raise (IsADirectoryError('{} is not a file'.format(csvPath)))

        if (not csvPath.endswith('.csv')):
            raise (CSVNotFoundException('{} is not a csv'.format(csvPath)))

        country_code = pd.read_csv(csvPath, encoding='ISO-8859-1')
        country_code['country'] = country_code['country'].apply(lambda x: x.lower())
        return country_code

    def get_data_csv(self, csvPath):
        if not (os.path.exists(csvPath)):
            raise (FileNotFoundError('{} is not found'.format(csvPath)))

        if not (os.path.isfile(csvPath)):
            raise (IsADirectoryError('{} is not a file'.format(csvPath)))

        if (not csvPath.endswith('.csv')):
            raise (CSVNotFoundException('{} is not a csv'.format(csvPath)))

        print('Reading data from {}'.format(csvPath))
        dataset = pd.read_csv(csvPath, encoding='ISO-8859-1')
        return dataset

    def create_cuisine_bag(self):
        slice_strip = lambda x: [y.lower().strip() for y in x] if type(x) != float else x
        bag = set(
            [y for x in self.dataset['Cuisines'].str.split(',').apply(slice_strip) if type(x) != float for y in x])
        self.cuisine_bag = list(bag)

    def filter_cuisine(self, cuisine_list, dataset=None):
        bag = []
        if type(cuisine_list) != list:
            cuisine_list = [cuisine_list]
        #print(cuisine_list)
        for l in cuisine_list:
            #print(l)
            bag.extend([x for x in filter(lambda x: l in x, self.cuisine_bag)])
        bag_exp = '|'.join([x for x in bag])
        bag_exp = '(' + bag_exp + ')'
        #print(bag_exp)
        if (type(dataset) == None):
            dataset = self.dataset
        mask1 = dataset['Cuisines'].apply(lambda x: x.find(bag_exp) != None)
        data = dataset[mask1]
        # print (data)
        return data

    def filter_city(self, city):
        if city == None:
            raise (TypeError('City is not present'))
        mask = self.dataset['City'].apply(lambda x: city.lower() in x.lower())
        data = self.dataset[mask]
        # print (data)
        return data

    def filter_rating(self, dataset, min_rating):

        if type(min_rating) is not float:
            raise (TypeError('Only float values allowed'))
        elif not (min_rating >= 1) and (min_rating <= 5):
            raise (InvalidRangeException('Only from 1 to 5'))

        mask = dataset['Aggregate rating'] >= min_rating
        data = dataset[mask]
        return data


def filter_data(country=None, city=None, cuisine=None, rating=1, price_min_rate=1, price_max_rate=5, table_book='No',
                online_order='No'):
    clb = CollaborativeFilter('zomato.csv', 'Country-code.csv')
    if type(country) == str:
        print(country)
        data = clb.country_filter(country)
    elif type(city) == str:
        data = clb.filter_city(city)
    else:
        data = clb.dataset
    data = clb.filter_cuisine(cuisine, data)
    data = clb.filter_online_delivery(data, online_order)
    data = clb.filter_table_booking(data, table_book)
    data = clb.filter_rating(data, float(rating))
    if (price_min_rate > price_max_rate):
        raise (InvalidRangeException('Lower range should be less than upper range'))

    if price_min_rate >= 1 and price_max_rate <= 5:
        data = clb.filter_price_range(data, price_min_rate, price_max_rate)
    elif price_min_rate < 5:
        data = clb.filter_price_range(data, price_min_rate, 5)
    elif price_max_rate <= 5:
        data = clb.filter_price_range(data, 1, price_max_rate)
    else:
        data = clb.filter_avg_cost(data, price_min_rate, price_max_rate)

    return data

# %%
data = filter_data(city = 'agra', cuisine = ['gujarati'], rating = 4.5, price_min_rate= 1, price_max_rate= 5000)
# Out:
# Reading data from zomato.csv

# %%
data.head()
# Out:
#      Restaurant ID  Restaurant Name  Country Code  City  \
# 637        3400346  Sheroes Hangout             1  Agra
#
#                                                Address Locality  \
# 637  Opposite The Gateway Hotel, Fatehabad Road, Ta...  Tajganj
#
#     Locality Verbose  Longitude  Latitude                     Cuisines  ...   \
# 637    Tajganj, Agra  78.040165  27.16185  Cafe, North Indian, Chinese  ...
#
#                Currency Has Table booking Has Online delivery  \
# 637  Indian Rupees(Rs.)                No                  No
#
#     Is delivering now Switch to order menu Price range  Aggregate rating  \
# 637                No                   No           1               4.9
#
#      Rating color Rating text Votes
# 637    Dark Green   Excellent    77
#
# [1 rows x 21 columns]
